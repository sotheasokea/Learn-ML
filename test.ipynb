# %% [markdown]
# <a href="https://colab.research.google.com/github/sotheasokea/Learn-ML/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("test")
# Out:
# test

# %%
# !git clone https://github.com/sotheasokea/Learn-ML.git
# Out:
# Cloning into 'Learn-ML'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# !ls
# Out:
# Learn-ML  sample_data
